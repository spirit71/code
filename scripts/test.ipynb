# %%
import torch
x=torch.randn(2, 3, 4)
print(x)
x=x[:, 1:,:]
print(x)
# Out:
# tensor([[[-0.2274, -0.7141,  1.4825, -0.0035],
#          [-1.1887, -1.8116,  0.7990,  0.6221],
#          [ 0.3803,  1.7692, -1.7437,  0.8428]],
#
#         [[-2.4839,  0.0939, -2.1115,  0.9492],
#          [ 1.2669, -0.3833,  0.2137,  1.5099],
#          [ 1.9381, -0.7510, -0.7274,  0.8787]]])
# tensor([[[-1.1887, -1.8116,  0.7990,  0.6221],
#          [ 0.3803,  1.7692, -1.7437,  0.8428]],
#
#         [[ 1.2669, -0.3833,  0.2137,  1.5099],
#          [ 1.9381, -0.7510, -0.7274,  0.8787]]])
